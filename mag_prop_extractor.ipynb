# %%
from mag_prop_tools import mag_pro_extractor

# %%
csv_file_path = "./01_figures"
csv_image_name = "S1_00536_fig_S6.png"
csv_file_name = "S1_00536_fig_S6_28nm.csv"
unit_x = 'H (kOe)'
unit_y = 'emu/g Fe'
min_x = -3
max_x = 3
min_y = -80
max_y = 80
mag_pro_extractor(csv_file_path,csv_image_name, csv_file_name, unit_x, unit_y,min_x,max_x,min_y,max_y)
# Out:
# Mr: 14.44 emu/g Fe
# Hc: 0.27 H (kOe)
# Ms: 82.93 emu/g Fe (*)
# (*): Cannot be calculated accurately

# %%
from mag_prop_tools import DLS_plot_extractor

# %%
csv_file_path = "./01_figures"
csv_image_name = "S0_2019_001_fig_3.png"
csv_file_name = "S0_2019_001_fig_3_S0.csv"
feature_x = 'Hydrodynamic size'
unit_x = 'nm'
feature_y = 'Intesity'
unit_y = '%'
min_x = 10
max_x = 1000
min_y = 0
max_y = 20
type_graph = 'line' # scatter or line
x_axis_log = True # True or False
peak_detect = 'auto' # auto or manual
peak_start = 10
peak_end = 150

DLS_plot_extractor(csv_file_path, csv_image_name, csv_file_name, feature_x, unit_x, feature_y, unit_y,
                      min_x, max_x, min_y, max_y,type_graph,x_axis_log, peak_detect, peak_start, peak_end)
# Out:
# Average diameter: 54.82 nm
# Weighted standard deviation: 28.67 nm
# Diameter at max Intesity (10.91%): 50.89 nm
# Polydispersity Index (PDI): 0.2735

# %%
# Get the CSV file name and path from user input
csv_file_path = "./01_figures"
csv_image_name = "S4_00802_R3_fig_6c.png"
csv_file_name = "S4_00802_R3_fig_6c_Co1.csv"
feature_x = 'time'
unit_x = 'seg'# min of seg
unit_y = '°C'
min_x = 0
max_x = 2000
min_y = 0
max_y = 70
feature_y = 'delta_temperature' # delta_temperature or temperature
#delta_time = 'auto' # 'auto' or 'manual'
heat_capacity_JgC = (4.184+0.67) # J/gC
mass_MNP_g = 5/1000 # g
mass_medium_g = 1.0 # g
density_medium_gcm3 = 1.0 # g/cm3

# %%
from mag_prop_tools import SAR_Bekovic_Hamler_extractor

SAR_Bekovic_Hamler_extractor(csv_file_path,csv_image_name,csv_file_name,feature_x, unit_x,feature_y,unit_y,min_x, max_x, min_y, max_y,
                                 heat_capacity_JgC,mass_MNP_g,mass_medium_g)
# Out:
# Fitted tau = 337.20 seg
# Initial Slope: 0.17 °C/seg
# SAR = 160.51 W/g
